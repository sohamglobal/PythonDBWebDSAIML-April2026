# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 18.0 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.dpfu46o.mongodb.net/?appName=SharayuCluster")

# %%
db=client["sohamdb"]

# %%
usrcoll=db["users"]

# %%
uid=input("Enter UserID : ")
ps=input("Enter password : ")
gn=input("Enter Gender : ")
ct=input("Enter City : ")

dic={}
dic['userid']=uid
dic['password']=ps
dic['gender']=gn
dic['city']=ct
print(dic)

usrcoll.insert_one(dic)
print('New user document added to the mongodb collection')
# Out:
# Enter UserID : praffull
# Enter password : chelsea
# Enter Gender : male
# Enter City : london
# {'userid': 'praffull', 'password': 'chelsea', 'gender': 'male', 'city': 'london'}
# New user document added to the mongodb collection

# %%
db2=client["spiderdb"]

# %%
frcoll=db2["friends"]

# %%
nm=input('Enter name : ')
dt=input('Enter date of birth : ')
hob=input('Enter hobbies seperated by comma : ')
hoblst=hob.split(',')
#print(hoblst)

dic={}
dic['name']=nm
dic['dob']=dt
dic['hobbies']=hoblst
print(dic)

frcoll.insert_one(dic)
print('New friend added...')
# Out:
# Enter name : shailaja
# Enter date of birth : 26 june
# Enter hobbies seperated by comma : reading,writing,tv
# {'name': 'shailaja', 'dob': '26 june', 'hobbies': ['reading', 'writing', 'tv']}
# New friend added...
