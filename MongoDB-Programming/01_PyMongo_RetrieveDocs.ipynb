# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 32.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 18.2 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://praffull:mongodb913@sharayucluster.dpfu46o.mongodb.net/?appName=SharayuCluster")

# %%
db=client["spiderdb"]

# %%
wcoll=db["coworkers"]

# %%
for doc in wcoll.find():
  print(doc)
# Out:
# {'_id': ObjectId('6a44846b77f8c56ee9654943'), 'name': 'Amit Sharma', 'gender': 'Male', 'age': 28, 'department': 'IT', 'post': 'Software Developer', 'location': 'Pune', 'salary': 65000}
# {'_id': ObjectId('6a44846b77f8c56ee9654944'), 'name': 'Priya Deshmukh', 'gender': 'Female', 'age': 31, 'department': 'HR', 'post': 'HR Manager', 'location': 'Mumbai', 'salary': 72000}
# {'_id': ObjectId('6a44846b77f8c56ee9654945'), 'name': 'Rahul Verma', 'gender': 'Male', 'age': 35, 'department': 'Finance', 'post': 'Accountant', 'location': 'Nagpur', 'salary': 68000}
# {'_id': ObjectId('6a44846b77f8c56ee9654946'), 'name': 'Sneha Kulkarni', 'gender': 'Female', 'age': 27, 'department': 'Marketing', 'post': 'Marketing Executive', 'location': 'Hyderabad', 'salary': 58000}
# {'_id': ObjectId('6a44846b77f8c56ee9654947'), 'name': 'Vikram Patil', 'gender': 'Male', 'age': 40, 'department': 'Sales', 'post': 'Sales Manager', 'location': 'Bengaluru', 'salary': 90000}
# ...

# %%
fcoll=db["friends"]

# %%
for doc in fcoll.find():
  print(doc)
# Out:
# {'_id': ObjectId('6a471f6059b8e7b65008148e'), 'name': 'sharayu', 'dob': '13 january', 'hobbies': ['drawing', 'coding', 'travel']}
# {'_id': ObjectId('6a47202c59b8e7b65008148f'), 'name': 'jos buttler', 'personal': {'height': 6.1, 'weight': 64, 'gender': 'male'}, 'city': 'london'}

# %%
db2=client["sohamdb"]

# %%
ucoll=db2["users"]

# %%
for doc in ucoll.find():
  print(doc)
# Out:
# {'_id': ObjectId('6a447e9677f8c56ee9654942'), 'userid': 'sharayu', 'password': 'backup', 'gender': 'female', 'city': 'london'}

# %%
filmscoll=db["films"]

# %%
for doc in filmscoll.find():
  print(doc)
# Out:
# {'_id': ObjectId('6a4725e559b8e7b650081490'), 'filmname': 'The Shawshank Redemption', 'releaseyear': 1994, 'genre': 'Drama', 'language': 'English', 'director': 'Frank Darabont', 'imdbrating': 9.3}
# {'_id': ObjectId('6a4725e559b8e7b650081491'), 'filmname': 'The Godfather', 'releaseyear': 1972, 'genre': 'Crime, Drama', 'language': 'English', 'director': 'Francis Ford Coppola', 'imdbrating': 9.2}
# {'_id': ObjectId('6a4725e559b8e7b650081492'), 'filmname': 'The Dark Knight', 'releaseyear': 2008, 'genre': 'Action, Crime, Drama', 'language': 'English', 'director': 'Christopher Nolan', 'imdbrating': 9.1}
# {'_id': ObjectId('6a4725e559b8e7b650081493'), 'filmname': 'The Godfather Part II', 'releaseyear': 1974, 'genre': 'Crime, Drama', 'language': 'English', 'director': 'Francis Ford Coppola', 'imdbrating': 9}
# {'_id': ObjectId('6a4725e559b8e7b650081494'), 'filmname': '12 Angry Men', 'releaseyear': 1957, 'genre': 'Drama', 'language': 'English', 'director': 'Sidney Lumet', 'imdbrating': 9}
# ...
