# %%
class Praffull:
  def __init__(self,name):
    print(f"your name is {name} and length is {len(name)}")

# %%
class Soham(Praffull):
  def __init__(self):
    super().__init__('sharayu')
    print("derived class constructor running...")

# %%
obj=Soham()
# Out:
# your name is sharayu and length is 7
# derived class constructor running...
