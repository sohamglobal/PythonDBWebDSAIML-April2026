# %%
s={'english','urdu','hindi','spanish','urdu','english'}
print(s)
print(type(s))
# Out:
# {'english', 'urdu', 'spanish', 'hindi'}
# <class 'set'>

# %%
s.add('french')
print(s)
# Out:
# {'urdu', 'hindi', 'spanish', 'english', 'french'}

# %%
print(s[3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3141/3567120435.py in <cell line: 0>()
# ----> 1 print(s[3])
#
# TypeError: 'set' object is not subscriptable

# %%
s.remove('french')
print(s)
# Out:
# {'urdu', 'hindi', 'spanish', 'english'}

# %%
mixed={'java',30,23.56,True}
print(mixed)
# Out:
# {True, 'java', 30, 23.56}

# %%
print(len(s))
print(max(s))
print(min(s))
# Out:
# 4
# urdu
# english

# %%
import sys

l=[1,2,3,4,5]
t=(1,2,3,4,5)
s={1,2,3,4,5}
r=range(5)

print(sys.getsizeof(l))
print(sys.getsizeof(t))
print(sys.getsizeof(s))
print(sys.getsizeof(r))
# Out:
# 104
# 80
# 472
# 48
