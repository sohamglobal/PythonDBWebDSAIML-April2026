# %%
myprofile=['praffull','mba',25,68.14,True]
print(myprofile)
print(type(myprofile))
# Out:
# ['praffull', 'mba', 25, 68.14, True]
# <class 'list'>

# %%
for val in myprofile:
  print(type(val))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
p=['praffull',25,68.14,['java','sql'],True]
print(p)
# Out:
# ['praffull', 25, 68.14, ['java', 'sql'], True]

# %%
p.append('9 june')
print(p)
p[3].append('mongodb')
print(p)
# Out:
# ['praffull', 25, 68.14, ['java', 'sql'], True, '9 june', '9 june']
# ['praffull', 25, 68.14, ['java', 'sql', 'mongodb'], True, '9 june', '9 june']
