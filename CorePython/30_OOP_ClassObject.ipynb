# %%
class Person:
  def welcome(self):
    print("welcome to OOP in Python")
  def thanks(self,name):
    print(f"Thanks {name} for joining SohamGlobal")

# %%
welcome()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5824/241228648.py in <cell line: 0>()
# ----> 1 welcome()
#
# NameError: name 'welcome' is not defined

# %%
obj=Person()

# %%
obj.welcome()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5824/485918977.py in <cell line: 0>()
# ----> 1 obj.welcome()
#
# TypeError: Person.welcome() takes 0 positional arguments but 1 was given

# %%
obj.thanks('praffull')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5824/1288465535.py in <cell line: 0>()
# ----> 1 obj.thanks('praffull')
#
# TypeError: Person.thanks() takes 1 positional argument but 2 were given

# %%
p=Person()

# %%
p.welcome()
# Out:
# welcome to OOP in Python

# %%
p.thanks('sharayu')
# Out:
# Thanks sharayu for joining SohamGlobal
