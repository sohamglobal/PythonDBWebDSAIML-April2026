# %% [markdown]
# **Integer**

# %%
x=9
print(type(x))
# Out:
# <class 'int'>

# %%
x='13'
print(type(x))
x=int(x)
print(type(x))
# Out:
# <class 'str'>
# <class 'int'>

# %%
print(abs(-15))
print(pow(5,2))
# Out:
# 15
# 25

# %% [markdown]
# **Float**

# %%
x=10.5
print(type(x))
# Out:
# <class 'float'>

# %%
x='13.9'
x=float(x)
print(type(x))
# Out:
# <class 'float'>

# %%
print(abs(-12.7))
print(round(14.3))
print(round(14.6))
# Out:
# 12.7
# 14
# 15

# %% [markdown]
# **Complex**

# %%
x=2+3j
print(x.real,x.imag)
# Out:
# 2.0 3.0

# %% [markdown]
# **String**

# %%
nm="praffull's password is chelsea@786"
print(nm)
print(type(nm))
# Out:
# praffull's password is chelsea@786
# <class 'str'>

# %% [markdown]
# **List**

# %%
lst=['praffull','sharayu','java','python','sql']
print(lst)
print(type(lst))
# Out:
# ['praffull', 'sharayu', 'java', 'python', 'sql']
# <class 'list'>

# %%
me='praffull,ethan hunt,london,7391966656,praffull@outlook.com,male'
print(type(me))
me=me.split(',')
print(me)
print(type(me))
# Out:
# <class 'str'>
# ['praffull', 'ethan hunt', 'london', '7391966656', 'praffull@outlook.com', 'male']
# <class 'list'>

# %% [markdown]
# **Tuple**

# %%
lst=('england','japan','germany','france')
print(lst)
print(type(lst))
# Out:
# ('england', 'japan', 'germany', 'france')
# <class 'tuple'>

# %% [markdown]
# **Range**

# %%
# start, stop, step
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **Set**

# %%
s={'java','microsoft','oracle','azure','spring'}
print(s)
print(type(s))
# Out:
# {'oracle', 'java', 'spring', 'azure', 'microsoft'}
# <class 'set'>

# %% [markdown]
# **Frozenset**

# %%
fs=frozenset([1,2,3,4,5])
print(fs)
print(type(fs))
# Out:
# frozenset({1, 2, 3, 4, 5})
# <class 'frozenset'>

# %% [markdown]
# **Dictionary**

# %%
d={"name":"praffull","city":"london","gender":"male"}
print(d)
print(type(d))
# Out:
# {'name': 'praffull', 'city': 'london', 'gender': 'male'}
# <class 'dict'>

# %% [markdown]
# **Boolean**

# %%
x=10>2
print(x)
print(type(x))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# **Binary**

# %%
nm=b'praffull'
print(nm)
print(type(nm))
# Out:
# b'praffull'
# <class 'bytes'>

# %% [markdown]
# **None**

# %%
x=None

print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>
