# %%
data=bytearray(b'Python Data Handling')
print(f"Original data : {data}")
# Out:
# Original data : bytearray(b'Python Data Handling')

# %%
view=memoryview(data)

# %%
view[0]=66

# %%
print(f"Modified data : {data}")
# Out:
# Modified data : bytearray(b'Bython Data Handling')

# %%
x=None
print(x)
print(type(x))
# Out:
# None
# <class 'NoneType'>

# %%
n=None
while n!=0:
  n=int(input('Enter a number '))
  print(n*n)
# Out:
# Enter a number 13
# 169
# Enter a number 9
# 81
# Enter a number 0
# 0
