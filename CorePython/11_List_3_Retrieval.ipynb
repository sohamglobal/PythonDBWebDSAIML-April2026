# %%
films=['the matrix','pk','sholay','speed','mission impossible','deewar']
actors=['tom cruise','amir khan','tabu','shabana azmi','smita patil']

# %%
films.extend(actors)
print(films)
# Out:
# ['the matrix', 'pk', 'sholay', 'speed', 'mission impossible', 'deewar', 'tom cruise', 'amir khan', 'tabu', 'shabana azmi', 'smita patil']

# %%
print(len(films))
# Out:
# 11

# %%
print(films[0])
# Out:
# the matrix

# %%
print(films[2:8])
# Out:
# ['sholay', 'speed', 'mission impossible', 'deewar', 'tom cruise', 'amir khan']

# %%
print(films[5:])
# Out:
# ['deewar', 'tom cruise', 'amir khan', 'tabu', 'shabana azmi', 'smita patil']

# %%
print(films[:5])
# Out:
# ['the matrix', 'pk', 'sholay', 'speed', 'mission impossible']

# %%
print(films[-1])
# Out:
# smita patil

# %%
print(films[::-1])
# Out:
# ['smita patil', 'shabana azmi', 'tabu', 'amir khan', 'tom cruise', 'deewar', 'mission impossible', 'speed', 'sholay', 'pk', 'the matrix']

# %%
for nm in films:
  print(nm.upper())
# Out:
# THE MATRIX
# PK
# SHOLAY
# SPEED
# MISSION IMPOSSIBLE
# DEEWAR
# TOM CRUISE
# AMIR KHAN
# TABU
# SHABANA AZMI
# SMITA PATIL

# %%
nm=input('Enter film/actor : ')
if nm in films:
  print(f'{nm} found in the list of films')
else:
  print('Not found')
# Out:
# Enter film/actor : The matrix
# Not found
