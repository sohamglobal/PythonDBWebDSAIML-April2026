# %%
me={
    'name':'praffull global',
    'qualification':'mba (mc)',
    'gender':'male',
    'profile':'consultant',
    'mobile':'7391966656'
}
print(me)
# Out:
# {'name': 'praffull global', 'qualification': 'mba (mc)', 'gender': 'male', 'profile': 'consultant', 'mobile': '7391966656'}

# %%
print(me.keys())
# Out:
# dict_keys(['name', 'qualification', 'gender', 'profile', 'mobile'])

# %%
print(me.values())
# Out:
# dict_values(['praffull global', 'mba (mc)', 'male', 'consultant', '7391966656'])

# %%
for k in me.keys():
  print(k)
# Out:
# name
# qualification
# gender
# profile
# mobile

# %%
for v in me.values():
  print(v)
# Out:
# praffull global
# mba (mc)
# male
# consultant
# 7391966656

# %%
for i in me.items():
  print(i)
# Out:
# ('name', 'praffull global')
# ('qualification', 'mba (mc)')
# ('gender', 'male')
# ('profile', 'consultant')
# ('mobile', '7391966656')

# %%
sub=['science','maths','english']
marks=dict.fromkeys(sub,0)
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 0}

# %%
marks['english']=72
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 72}

# %%
marks['english']+=3
print(marks)
# Out:
# {'science': 0, 'maths': 0, 'english': 75}
