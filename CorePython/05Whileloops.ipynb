# %%
nm=''
while nm!='stop':
  nm=input('Enter name : ')
  if nm!='stop':
    print(f"welcome {nm} to my party")
# Out:
# Enter name : sharayu
# welcome sharayu to my party
# Enter name : emily
# welcome emily to my party
# Enter name : shailaja
# welcome shailaja to my party
# Enter name : stop

# %%
for i in range(1,6):
  n=int(input('Enter a number : '))
  sq=n**2
  print(f'square is {sq}')
# Out:
# Enter a number : 12
# square is 144
# Enter a number : 45
# square is 2025
# Enter a number : 57
# square is 3249
# Enter a number : 87
# square is 7569
# Enter a number : 49
# square is 2401

# %%
n=1
while n>0:
  n=int(input('Enter a number : '))
  sq=n**2
  print(f'square is {sq}')
# Out:
# Enter a number : 17
# square is 289
# Enter a number : 39
# square is 1521
# Enter a number : -9
# square is 81

# %%
while True:
  print('hello')
  break
# Out:
# hello

# %%
i=1

while i<=10:
  if i==5:
    break
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=0

while i<5:
  i+=1
  if i==3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
