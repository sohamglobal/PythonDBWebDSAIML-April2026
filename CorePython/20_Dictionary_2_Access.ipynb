# %%
student={
    "studname":"sharayu",
    "course":"spark",
    "mode":"live online",
    "time":"0630",
    "fees":12500
}
print(student)
# Out:
# {'studname': 'sharayu', 'course': 'spark', 'mode': 'live online', 'time': '0630', 'fees': 12500}

# %%
print(student['mode'])
# Out:
# live online

# %%
print(student['course'])
# Out:
# spark

# %%
player={
    'playername':'Dominik Szoboszlai',
    'club':'Liverpool',
    'position':'Midfielder',
    'healthparameters':{
        'age':26,
        'height':175,
        'weight':65
    },
    'contractends':'June 2028'
}

# %%
print(player['healthparameters']['height'])
# Out:
# 175

# %%
applicant={
    'appname':'shailaja',
    'gender':'female',
    'skillset':['asp.net core','sql server','azure'],
    'post':'back-end developer'
}

# %%
print(applicant['skillset'][1])
# Out:
# sql server

# %%
#print(applicant['gender'])
print(applicant.get('gender'))
# Out:
# female

# %%
print(applicant['mobile'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1942/479611368.py in <cell line: 0>()
# ----> 1 print(applicant['mobile'])
#
# KeyError: 'mobile'

# %%
print(applicant.get('mobile','not available'))
# Out:
# not available
