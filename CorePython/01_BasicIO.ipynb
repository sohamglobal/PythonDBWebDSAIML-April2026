# %% [markdown]
# # Notebook for basic input output in Python

# %%
nm=input('Enter your name : ')
print(f"Welcome {nm} to Online Python")
# Out:
# Enter your name : Mohammed Salah
# Welcome Mohammed Salah to Online Python

# %%
n=int(input('Enter a number: '))
sq=n*n
print(f"square of {n} is {sq}")
# Out:
# Enter a number: 26
# square of 26 is 676

# %%
a=float(input('Enter first number : '))
b=float(input('Enter second number : '))
c=a+b
print(f"sum of {a} and {b} is {c}")
# Out:
# Enter first number : 12.81
# Enter second number : 27.16
# sum of 12.81 and 27.16 is 39.97

# %%
nm=input('Enter customer name : ')
amt=float(input('Enter purchase amount : '))
disc=amt*9/100
print(f'Dear {nm} you will get discount {disc} on your shopping of {amt}')
# Out:
# Enter customer name : soham
# Enter purchase amount : 12470
# Dear soham you will get discount 1122.3 on your shopping of 12470.0
