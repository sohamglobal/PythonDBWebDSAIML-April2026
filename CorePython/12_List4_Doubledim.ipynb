# %%
lst=[
    [1,2,3,7,0],
    [4,5,6,12,6],
    [7,8,9,2,5],
    [6,1,5,9,2]
]

print(lst)
# Out:
# [[1, 2, 3, 7, 0], [4, 5, 6, 12, 6], [7, 8, 9, 2, 5], [6, 1, 5, 9, 2]]

# %%
print(lst[1][3])
# Out:
# 12

# %%
print(lst[3])
# Out:
# [6, 1, 5, 9, 2]

# %%
print(lst[-2])
# Out:
# [7, 8, 9, 2, 5]

# %%
print(lst[:2][1])
# Out:
# [4, 5, 6, 12, 6]

# %%
print(lst[2:])
# Out:
# [[7, 8, 9, 2, 5], [6, 1, 5, 9, 2]]

# %%
print(lst[2:][1])
# Out:
# [6, 1, 5, 9, 2]

# %%
print(lst[2:][1][3])
# Out:
# 9

# %%
lst=[
    [1,2,3,7,0],
    [4,5,6,12,6],
    [7,8,9,2,5],
    [6,1,5,9,2]
]

col=[lst[r][1] for r in range(4)]
print(col)
# Out:
# [2, 5, 8, 1]

# %% [markdown]
# for complex 2D data advanced python prefers NumPy Arrays
