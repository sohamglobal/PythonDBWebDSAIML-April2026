# %%
nums=[9,26,13,1,45,30,10]
print(nums)
print(type(nums))
# Out:
# [9, 26, 13, 1, 45, 30, 10]
# <class 'list'>

# %%
nums.append(75)
print(nums)
# Out:
# [9, 26, 13, 1, 45, 30, 10, 75]

# %%
nums.append(13)
print(nums)
# Out:
# [9, 26, 13, 1, 45, 30, 10, 75, 13]

# %%
nm=[]
print(type(nm))
nm.append('praffull')
nm.append('sharayu')
nm.append('java')
nm.append('python')
print(nm)
# Out:
# <class 'list'>
# ['praffull', 'sharayu', 'java', 'python']

# %%
nm.insert(2,'cloud')
print(nm)
# Out:
# ['praffull', 'sharayu', 'cloud', 'java', 'python']

# %%
nm.remove('praffull')
print(nm)
# Out:
# ['sharayu', 'cloud', 'java', 'python']

# %%
db=['oracle','mongodb','mysql']
nm.extend(db)
print(nm)
# Out:
# ['sharayu', 'cloud', 'java', 'python', 'oracle', 'mongodb', 'mysql']

# %%
#retrieve and remove last item
print(nm.pop())
print(nm)
# Out:
# mysql
# ['sharayu', 'cloud', 'java', 'python', 'oracle', 'mongodb']

# %%
#nm.sort()
nm.sort(reverse=True)
print(nm)
# Out:
# ['sharayu', 'python', 'oracle', 'mongodb', 'java', 'cloud']

# %%
friends=['buttler','cummins','salah','starc','smith','root']
print(friends)
friends.reverse()
print(friends)
# Out:
# ['buttler', 'cummins', 'salah', 'starc', 'smith', 'root']
# ['root', 'smith', 'starc', 'salah', 'cummins', 'buttler']

# %%
for nm in friends:
  print(nm.capitalize())
# Out:
# Root
# Smith
# Starc
# Salah
# Cummins
# Buttler
