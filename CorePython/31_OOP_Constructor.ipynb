# %%
class Customer:
  def __init__(self,store):
    print(f"Welcome to {store}")
  def __init__(self,store,city):
    print(f"welcome to {store} {city}")
  def calcdiscount(self,amount):
    if amount>=20000:
      discount=amount*13/100
    else:
      discount=amount*9/100

    bill=amount-discount
    print(f"Amount : {amount}")
    print(f"Discount : {discount}")
    print(f"Net Bill : {bill}")

# %%
obj=Customer("walmart","amravati")
# Out:
# welcome to walmart amravati

# %%
c=Customer("dmart")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1871/2694498120.py in <cell line: 0>()
# ----> 1 c=Customer("dmart")
#
# TypeError: Customer.__init__() missing 1 required positional argument: 'city'

# %%
obj.calcdiscount(12400)
# Out:
# Amount : 12400
# Discount : 1116.0
# Net Bill : 11284.0

# %%
class Student:
  def __init__(self):
    print(f"Welcome to the soham school exams")
  def showresult(self,name,marks):
    if marks>=35:
      print(f"{name} you are pass")
    else:
      print(f"{name} you are fail")

# %%
s=Student()
s.showresult('praffull',13)
# Out:
# Welcome to the soham school exams
# praffull you are fail
