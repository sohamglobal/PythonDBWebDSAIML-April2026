# %%
for i in range(1,11):
  print(f'welcome to sohamglobal {i}')
# Out:
# welcome to sohamglobal 1
# welcome to sohamglobal 2
# welcome to sohamglobal 3
# welcome to sohamglobal 4
# welcome to sohamglobal 5
# welcome to sohamglobal 6
# welcome to sohamglobal 7
# welcome to sohamglobal 8
# welcome to sohamglobal 9
# welcome to sohamglobal 10

# %%
for i in range(21,26):
  print(i)
# Out:
# 21
# 22
# 23
# 24
# 25

# %%
for i in range(51,75,3):
  print(i)
# Out:
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72

# %%
for i in range(20,0,-2):
  print(i)
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2

# %%
skills=['java','python','sql','mongodb','spring','pyspark']

for nm in skills:
  print(nm)
# Out:
# java
# python
# sql
# mongodb
# spring
# pyspark

# %%
for ch in 'praffull':
  print(ch)
# Out:
# p
# r
# a
# f
# f
# u
# l
# l

# %%
for i in range(1,4):
  for j in range(15,19):
    print(f"i={i}, j={j}")
# Out:
# i=1, j=15
# i=1, j=16
# i=1, j=17
# i=1, j=18
# i=2, j=15
# i=2, j=16
# i=2, j=17
# i=2, j=18
# i=3, j=15
# i=3, j=16
# i=3, j=17
# i=3, j=18

# %%
n=int(input('Enter a number : '))
for i in range(1,11):
  print(n*i)
# Out:
# Enter a number : 13
# 13
# 26
# 39
# 52
# 65
# 78
# 91
# 104
# 117
# 130
