# %%
t=(1,2,3,4,5)
print(t)
print(type(t))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
# t.append(9)
# t.insert(2,9)
# t.remove(3)
# t.sort()
# t.reverse()
# t.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7899/244156543.py in <cell line: 0>()
#       4 # t.sort()
#       5 # t.reverse()
# ----> 6 t.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t=('praffull','java','sql','cloud','openai')
print(t)
# Out:
# ('praffull', 'java', 'sql', 'cloud', 'openai')

# %%
print(t[2])
# Out:
# sql

# %%
print(t[3:])
# Out:
# ('cloud', 'openai')

# %%
print(len(t))
print(max(t))
print(min(t))
# Out:
# 5
# sql
# cloud

# %%
t=('praffull',9,68.14,False)
print(t)
for val in t:
  print(type(val))
# Out:
# ('praffull', 9, 68.14, False)
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
t=('praffull',9,68.14,False,('9 june','mba'))
print(t)
print(t[4])
# Out:
# ('praffull', 9, 68.14, False, ('9 june', 'mba'))
# ('9 june', 'mba')

# %%
t=('praffull',9,68.14,False,('9 june','mba'),['java','python','sql'])
print(t)
# Out:
# ('praffull', 9, 68.14, False, ('9 june', 'mba'), ['java', 'python', 'sql'])

# %%
t[5].insert(1,'spring')
print(t)
# Out:
# ('praffull', 9, 68.14, False, ('9 june', 'mba'), ['java', 'spring', 'python', 'sql'])

# %%
t[5].remove('python')
print(t)
# Out:
# ('praffull', 9, 68.14, False, ('9 june', 'mba'), ['java', 'spring', 'sql'])

# %%
t=('java','python','java')
print(t)
# Out:
# ('java', 'python', 'java')

# %%
comp=('microsoft','volkswagen','samsung','dell','hp')
print(comp.count('dell'))
print(comp.index('dell'))
# Out:
# 1
# 3

# %%
import sys
lst=[1,2,3,4,5]
tup=(1,2,3,4,5)

print(sys.getsizeof(lst))
print(sys.getsizeof(tup))
# Out:
# 104
# 80

# %%
import timeit

list_time=timeit.timeit('x=[1,2,3,4,5]',number=100000)
tup_time=timeit.timeit('x=(1,2,3,4,5)',number=100000)

print(list_time)
print(tup_time)
# Out:
# 0.0061622039993380895
# 0.0014670080008727382
