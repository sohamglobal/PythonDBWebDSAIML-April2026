# %%
d={}
print(type(d))
# Out:
# <class 'dict'>

# %%
d=dict()
print(type(d))
# Out:
# <class 'dict'>

# %%
emp={
    "empname":"jos buttler",
    "department":"marketing",
    "location":"london",
    "salary":34500.00
}
print(emp)
print(type(emp))
# Out:
# {'empname': 'jos buttler', 'department': 'marketing', 'location': 'london', 'salary': 34500.0}
# <class 'dict'>

# %%
stud=dict(studname='sharayu',course='spring boot',feespaid=2500)
print(stud)
print(type(stud))
# Out:
# {'studname': 'sharayu', 'course': 'spring boot', 'feespaid': 2500}
# <class 'dict'>

# %% [markdown]
# Array of values in a dictionary

# %%
applicant={
    'appname':'shailaja',
    'gender':'female',
    'skillset':['asp.net core','sql server','azure'],
    'post':'back-end developer'
}
print(applicant)
print(type(applicant))
# Out:
# {'appname': 'shailaja', 'gender': 'female', 'skillset': ['asp.net core', 'sql server', 'azure'], 'post': 'back-end developer'}
# <class 'dict'>

# %% [markdown]
# Nested dict or nested document

# %%
player={
    'playername':'Dominik Szoboszlai',
    'club':'Liverpool',
    'position':'Midfielder',
    'healthparameters':{
        'age':26,
        'height':175,
        'weight':65
    },
    'contractends':'June 2028'
}

# %%
k=['patientname','age','city','illness']
v=['john doe',35,'new york','migrane']
patient=dict(zip(k,v))
print(patient)
print(type(patient))
# Out:
# {'patientname': 'john doe', 'age': 35, 'city': 'new york', 'illness': 'migrane'}
# <class 'dict'>

# %%
patient['age']=37
print(patient)
# Out:
# {'patientname': 'john doe', 'age': 37, 'city': 'new york', 'illness': 'migrane'}

# %%
me={}
print(type(me))
# Out:
# <class 'dict'>

# %%
me['name']='praffull'
me['codename']='ethan hunt'
me['dob']='9 june'
me['gender']='male'
me['city']='london'

print(me)
# Out:
# {'name': 'praffull', 'codename': 'ethan hunt', 'dob': '9 june', 'gender': 'male', 'city': 'london'}
