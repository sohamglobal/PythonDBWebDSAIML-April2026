# %%
nm='sohamglobal is a microsoft and aws partner'

# %%
print(nm.upper())
print(nm.lower())
print(nm.capitalize())
print(nm.title())
# Out:
# SOHAMGLOBAL IS A MICROSOFT AND AWS PARTNER
# sohamglobal is a microsoft and aws partner
# Sohamglobal is a microsoft and aws partner
# Sohamglobal Is A Microsoft And Aws Partner

# %%
city='   london    '
print(f"my city is {city} and i like it")
print(f"my city is {city.strip()} and i like it")
print(f"my city is {city.lstrip()} and i like it")
print(f"my city is {city.rstrip()} and i like it")
# Out:
# my city is    london     and i like it
# my city is london and i like it
# my city is london     and i like it
# my city is    london and i like it

# %%
slogan="you will never walk alone"
slogan=slogan.replace("walk","communicate")
print(slogan)
# Out:
# you will never communicate alone

# %%
slogan="you will never walk alone"
print(slogan.split())
film="the matrix,1999,action,english,wachowsky,keanu reeves,9.1"
print(film.split(','))
# Out:
# ['you', 'will', 'never', 'walk', 'alone']
# ['the matrix', '1999', 'action', 'english', 'wachowsky', 'keanu reeves', '9.1']

# %%
nm='sohamglobal'
print(nm.find('m'))
print(nm.find('p'))
print(nm.find('o'))
print(nm.rfind('o'))
# Out:
# 4
# -1
# 1
# 7

# %%
print('-'.join(['soham','global','praffull','sharayu']))
# Out:
# soham-global-praffull-sharayu

# %%
txt="volkswagen is my car company"
print(txt.find('honda'))
print(txt.find('car'))
print(txt.index('car'))
print(txt.index('honda')) #exception handling
# Out:
# -1
# 17
# 17
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_671/1835970805.py in <cell line: 0>()
#       3 print(txt.find('car'))
#       4 print(txt.index('car'))
# ----> 5 print(txt.index('honda'))
#
# ValueError: substring not found

# %%
ques="What is the capital of England?"
print(ques.startswith('what'))
print(ques.startswith('What'))
print(ques.endswith('?'))
# Out:
# False
# True
# True

# %%
nm='praffull'
print(nm.isalpha())
code='431604 '
print(code.isdigit())

if code.isdigit():
  n=int(code)
  n+=10
  print(n)

ps='chelsea786'
print(ps.isalnum())
txt=''
print(txt.isspace())
# Out:
# True
# False
# True
# False

# %%
nm=''
while nm.lower() !='stop':
  nm=input('Enter name : ')
  print(f"welcome {nm}")
# Out:
# Enter name : soham
# welcome soham
# Enter name : STop
# welcome STop

# %%
nm="SOhamGlobal"
print(nm.swapcase())
# Out:
# soHAMgLOBAL

# %%
n='13'
print(n.zfill(5))
# Out:
# 00013

# %%
print('hi'.ljust(10,'#'))
print('hi'.rjust(10,'#'))
print('hi'.center(10,'#'))
# Out:
# hi########
# ########hi
# ####hi####

# %%
msg="Dear {}, thanks for buying a {} car"
print(msg.format('praffull','volkswagen'))
print(msg.format('vaibhav','skoda'))
# Out:
# Dear praffull, thanks for buying a volkswagen car
# Dear vaibhav, thanks for buying a skoda car

# %%
nm=input('Enter your name : ')
if nm.lower().strip()=='praffull':
  print('what an amazing name this!')
else:
  print('very ordinary name')
# Out:
# Enter your name : PraffuLL
# what an amazing name this!

# %%
slogan="tachnology is power technology is future"
print(len(slogan))
print(max(slogan))
print(min(slogan))
# Out:
# 40
# y
