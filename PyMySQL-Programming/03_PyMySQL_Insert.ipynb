# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-27706bd3-praffull-project.d.aivencloud.com',port=14602,user='avnadmin',password='AVNS_yyFqLbIXvQq6c_LMztu',database='defaultdb')

# %%
cursor=connection.cursor()

# %% [markdown]
# **Take input from the user**

# %%
no=int(input('Enter student registration number : '))
nm=input('Enter name : ')
ct=input('Enter city : ')
co=input('Course joined : ')
fs=float(input('Enter fees : '))
# Out:
# Enter student registration number : 124
# Enter name : joe root
# Enter city : manchester
# Course joined : ai agents
# Enter fees : 12500

# %%
cursor.execute(f"insert into students values({no},'{nm}','{ct}','{co}',{fs})")
# Out:
# 1

# %%
connection.commit()

# %%
ano=int(input('Enter account number : '))
anm=input('Enter name : ')
aty=input('Enter type : ')
bal=float(input('Enter balance : '))
# Out:
# Enter account number : 1101
# Enter name : Mohammed Salah
# Enter type : saving
# Enter balance : 79300

# %%
cursor.execute(f"insert into accounts values({ano},'{anm}','{aty}',{bal})")
# Out:
# 1

# %%
connection.commit()

# %%
nm=input('Enquiry name : ')
br=input('Brand interest : ')
# Out:
# Enquiry name : Rashmi
# Brand interest : Skoda

# %%
cursor.execute(f"insert into enquiries(name,interestedin) values('{nm}','{br}')")
connection.commit()

# %%
connection.close()
