# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.2.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.2.0

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-27706bd3-praffull-project.d.aivencloud.com',port=14602,user='avnadmin',password='AVNS_yyFqLbIXvQq6c_LMztu',database='defaultdb')

# %%
cursor=connection.cursor()

# %%
no=int(input('Enter account number to delete : '))
# Out:
# Enter account number to delete : 1062

# %%
cursor.execute(f"select * from accounts where accno={no}")
data=cursor.fetchone()
if data:
  print(data)
  cho=input('Do you want to delete? (yes/no) ')
  if cho=='yes':
    cursor.execute(f"delete from accounts where accno={no}")
    connection.commit()
    print('account deleted')
  else:
    print('delete cancelled')
else:
  print('not found')
# Out:
# (1062, 'Hardik Pandya', 'ppf', 95000.0)
# Do you want to delete? (yes/no) yes
# account deleted

# %%
connection.close()
