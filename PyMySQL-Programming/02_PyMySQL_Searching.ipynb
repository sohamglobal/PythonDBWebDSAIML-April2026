# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 2.3 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
connection=pymysql.connect(host='mysql-27706bd3-praffull-project.d.aivencloud.com',port=14602,user='avnadmin',password='AVNS_yyFqLbIXvQq6c_LMztu',database='defaultdb')

# %%
cursor=connection.cursor()

# %%
typ=input('Enter account type : ')
cursor.execute(f"select * from accounts where acctype='{typ}'")
data=cursor.fetchall()
print(data)
# Out:
# Enter account type : current
# ((1052, 'Shah Rukh Khan', 'current', 1250000.0), (1056, 'Deepika Padukone', 'current', 840000.0), (1060, 'Jasprit Bumrah', 'current', 320000.0), (1064, 'KL Rahul', 'current', 185000.0), (1068, 'Shikhar Dhawan', 'current', 75000.5), (1072, 'Shreyas Iyer', 'current', 42000.0), (1076, 'Shubman Gill', 'current', 98000.8), (1080, 'Ravichandran Ashwin', 'current', 115000.0), (1084, 'Ishant Sharma', 'current', 55000.0), (1088, 'Yuzvendra Chahal', 'current', 38000.2), (1092, 'Bhuvneshwar Kumar', 'current', 67000.5), (1096, 'Shardul Thakur', 'current', 52000.0), (1100, 'Ishan Kishan', 'current', 83000.5))

# %%
cur2=connection.cursor()
sp=input('Enter specialization : ')
cur2.execute(f"select * from doctors where specialization='{sp}'")
data=cur2.fetchall()
print(data)
# Out:
# Enter specialization : cardiologist
# ((1, 'Dr. Smith', 'Cardiologist', 15),)

# %%
no=input('Enter account number : ')
cur3=connection.cursor()
cur3.execute(f"select * from accounts where accno={no}")
data=cur3.fetchone()
print(data)
# Out:
# Enter account number : 1077
# (1077, 'Anushka Sharma', 'fixed', 720000.0)
